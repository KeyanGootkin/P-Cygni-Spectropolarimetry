# %%
from corner import corner
import pandas as pd
import numpy as np

# %%
bdf = pd.read_csv("C:/Users/Keyan/Desktop/Science/Data/P-Cygni/Data/bigtable.txt")
data = np.array([bdf.MJD,bdf.q1,bdf.u1,bdf.Error1,bdf.q2,bdf.u2,bdf.Error2]).T

# %%
corner(data,labels=["MJD","V-q","V-u","V Error","H-q","H-u","H Error"])
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
